# %%
# 라이브러리 임포트
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup as bsp
import matplotlib
import matplotlib.pyplot as plt
import sqlite3
import re
from datetime import datetime, timedelta,date
import sys
import os

os.chdir('C:\\Users\\pcsea\\work1\\Self_study\\Company_news_PJ\\KOSPI200_NEWS')
corplist200 = pd.read_csv('corplist200_m.csv', encoding='cp949')

# %%
corplist2001 = []
for i in range(len(corplist200)):
    target = corplist200['code'][i]
    corplist2001.append('{0:06d}'.format(target))
corplist200['code'] = corplist2001
corplist200
# Out:
#       company    code
# 0        삼성전자  005930
# 1      SK하이닉스  000660
# 2        LG화학  051910
# 3         현대차  005380
# 4    삼성바이오로직스  207940
# ..        ...     ...
# 132      일양약품  007570
# 133    JW중외제약  001060
# 134     SPC삼립  005610
# 135       삼양사  145990
# 136       빙그레  005180
#
# [137 rows x 2 columns]

# %%
corplist200[:50]
# Out:
#      company    code
# 0       삼성전자  005930
# 1     SK하이닉스  000660
# 2       LG화학  051910
# 3        현대차  005380
# 4   삼성바이오로직스  207940
# 5        카카오  035720
# 6      삼성SDI  006400
# 7        기아차  000270
# 8      POSCO  005490
# 9      현대모비스  012330
# 10      LG전자  066570
# 11    LG생활건강  051900
# 12      삼성물산  028260
# 13      KB금융  105560
# 14     SK텔레콤  017670
# 15     엔씨소프트  036570
# 16   SK이노베이션  096770
# 17      신한지주  055550
# 18      삼성생명  032830
# 19      한국전력  015760
# 20    아모레퍼시픽  090430
# 21      삼성전기  009150
# 22    하나금융지주  086790
# 23     롯데케미칼  011170
# 24     한온시스템  018880
# 25      삼성화재  000810
# 26   LG디스플레이  034220
# 27      고려아연  010130
# 28      금호석유  011780
# 29    현대글로비스  086280
# 30      기업은행  024110
# 31    CJ제일제당  097950
# 32      현대제철  004020
# 33      강원랜드  035250
# 34    LG유플러스  032640
# 35      아모레G  002790
# 36       오리온  271560
# 37     LG이노텍  011070
# 38       이마트  139480
# 39    한국금융지주  071050
# 40      현대건설  000720
# 41       코웨이  021240
# ...

# %%
# 41	대한항공	003490 / 108	동원시스템즈	014820 / 114	세방전지	004490/ 134	삼양홀딩스	000070
# temttt = corplist200.drop(corplist200.index[41])
# temttt = temttt.drop(temttt.index[108])
# temttt = temttt.drop(temttt.index[114])

# temttt = temttt.drop(temttt.index[134]).reset_index(drop=True)

temttt = corplist200.drop(temttt.index[134])
temttt = temttt.drop(temttt.index[114])
temttt = temttt.drop(temttt.index[108])

temttt = temttt.drop(corplist200.index[41]).reset_index(drop=True)

temttt[100:]
# Out:
#      company    code
# 100    코오롱인더  120110
# 101     부광약품  003000
# 102     대웅제약  069620
# 103   롯데정밀화학  004000
# 104   SK네트웍스  001740
# 105     한국콜마  161890
# 106    한전KPS  051600
# 107     코스맥스  192820
# 108  한올바이오파마  009420
# 109      이노션  214320
# 110     영진약품  003520
# 111     보령제약  003850
# 112    금호타이어  073240
# 113     동국제강  001230
# 114     LG상사  001120
# 115     롯데칠성  005300
# 116       영풍  000670
# 117      GKL  114090
# 118     태광산업  003240
# 119   현대그린푸드  005440
# 120      휴켐스  069260
# 121       한섬  020000
# 122    현대홈쇼핑  057050
# 123     한세실업  105630
# 124       풍산  103140
# 125   오리온홀딩스  001800
# 126       대상  001680
# 127   LIG넥스원  079550
# 128     한전기술  052690
# 129       두산  000150
# 130      락앤락  115390
# 131    동원F&B  049770
# 132    넥센타이어  002350
# 133   LG하우시스  108670
# 134     일양약품  007570
# 135   JW중외제약  001060
# 136    SPC삼립  005610
# 137      삼양사  145990
# 138      빙그레  005180

# %%
os.chdir('C:\\Users\\pcsea\\work1\\Self_study\\Company_news_PJ\\KOSPI200_NEWS')  # 여기 corplist200_m.csv이 있는 폴더
corplist200 = pd.read_csv('corplist200_m.csv', encoding='cp949')
corplist2001 = []
for i in range(len(corplist200)):
    target = corplist200['code'][i]
    corplist2001.append('{0:06d}'.format(target))
corplist200['code'] = corplist2001

corplist200
# Out:
#       company    code
# 0        삼성전자  005930
# 1      SK하이닉스  000660
# 2        LG화학  051910
# 3         현대차  005380
# 4    삼성바이오로직스  207940
# ..        ...     ...
# 132      일양약품  007570
# 133    JW중외제약  001060
# 134     SPC삼립  005610
# 135       삼양사  145990
# 136       빙그레  005180
#
# [137 rows x 2 columns]

# %%
# os.chdir('C:\\Users\\pcsea\\work1\\Self_study\\Company_news_PJ\\KOSPI200_NEWS')  # 여기 corplist200_m.csv이 있는 폴더
# corplist200 = pd.read_csv('corplist200_m.csv', encoding='cp949')
corplist200 = corplist200.drop(corplist200.index[123]).reset_index(drop=True)
corplist200 = corplist200.drop(corplist200.index[40]).reset_index(drop=True)

# %%
temttt = corplist200.copy()

# %%
temttt
# Out:
#       company    code
# 0        삼성전자  005930
# 1      SK하이닉스  000660
# 2        LG화학  051910
# 3         현대차  005380
# 4    삼성바이오로직스  207940
# ..        ...     ...
# 130      일양약품  007570
# 131    JW중외제약  001060
# 132     SPC삼립  005610
# 133       삼양사  145990
# 134       빙그레  005180
#
# [135 rows x 2 columns]

# %%
os.chdir('C:\\Users\\pcsea\\work1\\Self_study\\Company_news_PJ\\fdata')
from sklearn.metrics import accuracy_score
acc_score = []
for i in range(len(temttt)):
    coden = temttt['code'][i]
    name = coden +'_cos.csv'
    data = pd.read_csv(name, encoding='cp949')
    for j in range(len(data)):
        if data['pre_por'][j]>0.5:
            data['pre_por'][j]=1
        else:
            data['pre_por'][j]=0
    realud = np.array(data['polarity']).reshape(-1, 1)
    predud = np.array(data['pre_por']).reshape(-1, 1)
    print(i)
    print(temttt['company'][i])
    score = accuracy_score(realud,predud)
    acc_score.append(score)
# Out:
# C:\Users\pcsea\Anaconda3\envs\study\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\pcsea\Anaconda3\envs\study\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\pcsea\Anaconda3\envs\study\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
len(acc_score)
# Out:
# 135

# %%
temttt4 = temttt.copy()
temttt4
# Out:
#       company    code
# 0        삼성전자  005930
# 1      SK하이닉스  000660
# 2        LG화학  051910
# 3         현대차  005380
# 4    삼성바이오로직스  207940
# ..        ...     ...
# 130      일양약품  007570
# 131    JW중외제약  001060
# 132     SPC삼립  005610
# 133       삼양사  145990
# 134       빙그레  005180
#
# [135 rows x 2 columns]

# %%
temttt4['acc_cos'] = acc_score
temttt4
# Out:
#       company    code   acc_cos
# 0        삼성전자  005930  0.566667
# 1      SK하이닉스  000660  0.517857
# 2        LG화학  051910  0.566038
# 3         현대차  005380  0.500000
# 4    삼성바이오로직스  207940  0.666667
# ..        ...     ...       ...
# 130      일양약품  007570  0.200000
# 131    JW중외제약  001060  0.625000
# 132     SPC삼립  005610  0.214286
# 133       삼양사  145990  0.461538
# 134       빙그레  005180  0.684211
#
# [135 rows x 3 columns]

# %%
temttt4.mean()
# Out:
# code            inf
# acc_cos    0.530459
# dtype: float64

# %%
temttt4.to_csv('NLP_코사인유사도정확도.csv', encoding='cp949', index=False)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\pcsea\\work1\\Self_study\\Company_news_PJ\\fdata'

# %%
temttt4[:35]
# Out:
#      company    code   acc_cos
# 0       삼성전자  005930  0.566667
# 1     SK하이닉스  000660  0.517857
# 2       LG화학  051910  0.566038
# 3        현대차  005380  0.500000
# 4   삼성바이오로직스  207940  0.666667
# 5        카카오  035720  0.573770
# 6      삼성SDI  006400  0.621622
# 7        기아차  000270  0.490566
# 8      POSCO  005490  0.466667
# 9      현대모비스  012330  0.458333
# 10      LG전자  066570  0.559322
# 11    LG생활건강  051900  0.444444
# 12      삼성물산  028260  0.468750
# 13      KB금융  105560  0.583333
# 14     SK텔레콤  017670  0.538462
# 15     엔씨소프트  036570  0.476190
# 16   SK이노베이션  096770  0.583333
# 17      신한지주  055550  0.454545
# 18      삼성생명  032830  0.375000
# 19      한국전력  015760  0.629630
# 20    아모레퍼시픽  090430  0.512821
# 21      삼성전기  009150  0.391304
# 22    하나금융지주  086790  0.714286
# 23     롯데케미칼  011170  0.444444
# 24     한온시스템  018880  0.818182
# 25      삼성화재  000810  0.454545
# 26   LG디스플레이  034220  0.379310
# 27      고려아연  010130  0.666667
# 28      금호석유  011780  0.621622
# ...
